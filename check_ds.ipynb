# %%
from datasets import enchant_n, advice
import matplotlib.pyplot as plt
import torch

# %%
test_ds = advice.AdviceOneOptionDataset('data/advice_gen')

# %%
len(test_ds)
# Out:
# 380160

# %%
plt.imshow(test_ds[380000][0].permute(1,2,0))
plt.show()

# %%
test_ds[111][0].shape
# Out:
# torch.Size([3, 64, 288])
