# %%
from datasets import enchant_n, advice
import matplotlib.pyplot as plt
import torch

# %%
test_ds = advice.AdviceTwoOptionDataset('data/advice_gen')

# %%
len(test_ds)
# Out:
# 2724480

# %%
idx = 1000000
plt.imshow(test_ds[idx][0].permute(1,2,0))
plt.show()
print(test_ds[idx][1])
print(test_ds[idx][2])
# Out:
# 19
# 14

# %%
test_ds[111][0].shape
# Out:
# torch.Size([3, 64, 288])
