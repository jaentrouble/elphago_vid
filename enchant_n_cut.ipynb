# %%
from PIL import Image
from pathlib import Path
import numpy as np
from matplotlib import pyplot as plt
import tqdm

# %%
for f in Path('data/raw/new/').glob('*.png'):
    img = Image.open(f)
    plt.imshow(img)
    plt.show()
    break

# %%
np_img = np.array(img)[952:977,920:985,1]
plt.imshow(np_img, cmap='gray')
np_img.shape
# Out:
# (25, 65)

# %%
count=220
for f in Path('data/raw/new/').glob('*.png'):
    img = Image.open(f)
    np_img = np.array(img)
    np_img = np_img[952:977,920:985]
    img = Image.fromarray(np_img)
    img.save(f'data/enchant_n_cut/{count}.png')
    count+=1
