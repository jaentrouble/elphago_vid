# %%
from PIL import Image
from pathlib import Path
import numpy as np
from matplotlib import pyplot as plt
import tqdm

# %%
for f in Path('data/raw/done/').glob('*.png'):
    img = Image.open(f)
    plt.imshow(img)
    plt.show()
    break

# %%
np_img = np.array(img)
plt.imshow(np_img[940:990,880:1050])

# %%
count=0
for f in Path('data/raw/done/').glob('*.png'):
    img = Image.open(f)
    np_img = np.array(img)
    np_img = np_img[940:990,880:1050]
    img = Image.fromarray(np_img)
    img.save(f'data/enchant_n_cut/{count}.png')
    count+=1
